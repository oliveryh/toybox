# %% [markdown]
# # Introduction

# %% [markdown]
# The following learning project is intended to help me learn concepts around the steps required to create a visualisation in python, but also expose the level of information that is stored by companies such as YouTube (Google).

# %% [markdown]
# ## Objectives
#
# * **Data Preparation:** Data preparation makes up ~80% of the work in a Data Science pipeline. I'd like to explore the best techniques to go from raw CSV data, to a cleaned up tabular format that is ready for data visualisation.
#     * [X] Data Preparation
#     * [ ]Feature Engineering
# * **Plot:** There are various modules that can be used to plot the data. I'll consider which is best for this use case, and find the best way to represent the data in hand.
#     * [ ] Plot representation within Jupyter Notebook
#     * [ ] Plot representation on webfront
# * **Web Display:** In order to display this project, what is the best way to allow users to upload their YouTube data and display the visualisation such that is can be deployed on a server with minimal effort to others.

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Getting access to YouTube Data
#
# YouTube depricated their history API due to privacy reasons a few years ago, however it's possible to download a copy of your YouTube history in a JSON format by doing the following:
#
# 1. Go to [Google Takeout](https://takeout.google.com/)
# 2. Deselect All
# 3. Select YouTube
# 4. Underneath YouTube, click on "All YouTube Data Included"
# 5. Deselect All
# 6. Select history
#
# You can then download your YouTube data after it is generated and a link sent to you. You should get a file called `watch-history.json` that we'll be making use of in future steps.

# %% [markdown]
# ## Data Preparation
#
# We can take a look at the JSON and see what there is:

# %%
import json
import pandas as pd

# Open History File as dataframe
file = '../watch-history.json'
with open(file, encoding='utf8') as wh_file:
    wh_dict = json.load(wh_file)
    
wh = pd.DataFrame.from_dict(wh_dict)

# %%
display(wh)
# Out:
#      description   header   products  \
# 0            NaN  YouTube  [YouTube]
# 1            NaN  YouTube  [YouTube]
# 2            NaN  YouTube  [YouTube]
# 3            NaN  YouTube  [YouTube]
# 4            NaN  YouTube  [YouTube]
# 5            NaN  YouTube  [YouTube]
# 6            NaN  YouTube  [YouTube]
# 7            NaN  YouTube  [YouTube]
# 8            NaN  YouTube  [YouTube]
# 9            NaN  YouTube  [YouTube]
# 10           NaN  YouTube  [YouTube]
# 11           NaN  YouTube  [YouTube]
# 12           NaN  YouTube  [YouTube]
# 13           NaN  YouTube  [YouTube]
# 14           NaN  YouTube  [YouTube]
# 15           NaN  YouTube  [YouTube]
# 16           NaN  YouTube  [YouTube]
# 17           NaN  YouTube  [YouTube]
# 18           NaN  YouTube  [YouTube]
# 19           NaN  YouTube  [YouTube]
# 20           NaN  YouTube  [YouTube]
# 21           NaN  YouTube  [YouTube]
# 22           NaN  YouTube  [YouTube]
# 23           NaN  YouTube  [YouTube]
# 24           NaN  YouTube  [YouTube]
# 25           NaN  YouTube  [YouTube]
# 26           NaN  YouTube  [YouTube]
# 27           NaN  YouTube  [YouTube]
# 28           NaN  YouTube  [YouTube]
# 29           NaN  YouTube  [YouTube]
# ...          ...      ...        ...
# 8995         NaN  YouTube  [YouTube]
# 8996         NaN  YouTube  [YouTube]
# 8997         NaN  YouTube  [YouTube]
# 8998         NaN  YouTube  [YouTube]
# 8999         NaN  YouTube  [YouTube]
# 9000         NaN  YouTube  [YouTube]
# 9001         NaN  YouTube  [YouTube]
# 9002         NaN  YouTube  [YouTube]
# 9003         NaN  YouTube  [YouTube]
# 9004         NaN  YouTube  [YouTube]
# 9005         NaN  YouTube  [YouTube]
# 9006         NaN  YouTube  [YouTube]
# 9007         NaN  YouTube  [YouTube]
# 9008         NaN  YouTube  [YouTube]
# 9009         NaN  YouTube  [YouTube]
# 9010         NaN  YouTube  [YouTube]
# 9011         NaN  YouTube  [YouTube]
# 9012         NaN  YouTube  [YouTube]
# 9013         NaN  YouTube  [YouTube]
# 9014         NaN  YouTube  [YouTube]
# 9015         NaN  YouTube  [YouTube]
# 9016         NaN  YouTube  [YouTube]
# 9017         NaN  YouTube  [YouTube]
# 9018         NaN  YouTube  [YouTube]
# 9019         NaN  YouTube  [YouTube]
# 9020         NaN  YouTube  [YouTube]
# 9021         NaN  YouTube  [YouTube]
# 9022         NaN  YouTube  [YouTube]
# 9023         NaN  YouTube  [YouTube]
# 9024         NaN  YouTube  [YouTube]
#
#                                               subtitles  \
# 0     [{'name': 'StromaeVEVO', 'url': 'https://www.y...
# 1     [{'name': 'Mick J Clark', 'url': 'https://www....
# 2     [{'name': 'Tech Insider', 'url': 'https://www....
# 3     [{'name': 'The Verge', 'url': 'https://www.you...
# 4     [{'name': 'Dan Croitor', 'url': 'https://www.y...
# 5     [{'name': 'Netflix', 'url': 'https://www.youtu...
# 6     [{'name': 'Dan Croitor', 'url': 'https://www.y...
# 7     [{'name': 'E4', 'url': 'https://www.youtube.co...
# 8     [{'name': 'ChrisFix', 'url': 'https://www.yout...
# 9     [{'name': 'TheEllenShow', 'url': 'https://www....
# 10    [{'name': 'CinemaSins', 'url': 'https://www.yo...
# 11    [{'name': 'Great Big Story', 'url': 'https://w...
# 12    [{'name': 'iggyazaleamusicVEVO', 'url': 'https...
# 13    [{'name': 'Jonathan Pie', 'url': 'https://www....
# 14    [{'name': 'All 4', 'url': 'https://www.youtube...
# 15    [{'name': 'Taylor Swift', 'url': 'https://www....
# 16    [{'name': 'Jim Sterling', 'url': 'https://www....
# 17    [{'name': 'Ryan Reynolds', 'url': 'https://www...
# 18    [{'name': 'TaylorSwiftVEVO', 'url': 'https://w...
# 19    [{'name': 'Jonathan Pie', 'url': 'https://www....
# 20    [{'name': 'TEDx Talks', 'url': 'https://www.yo...
# 21    [{'name': 'Nathaniel Drew', 'url': 'https://ww...
# 22    [{'name': 'Legal Latino Heat', 'url': 'https:/...
# 23    [{'name': 'TLC', 'url': 'https://www.youtube.c...
# 24    [{'name': 'Thomas Frank', 'url': 'https://www....
# 25    [{'name': 'NOVA PBS Official', 'url': 'https:/...
# 26    [{'name': 'PewDiePie', 'url': 'https://www.you...
# 27    [{'name': 'Metronomy', 'url': 'https://www.you...
# 28    [{'name': 'DaftPunkVEVO', 'url': 'https://www....
# 29    [{'name': 'StromaeVEVO', 'url': 'https://www.y...
# ...                                                 ...
# 8995  [{'name': 'SturdyPineTV', 'url': 'https://www....
# 8996  [{'name': 'evilaj2010', 'url': 'https://www.yo...
# 8997  [{'name': 'hduncan1100', 'url': 'https://www.y...
# 8998  [{'name': 'FamilyFeud', 'url': 'https://www.yo...
# 8999  [{'name': 'The Tonight Show Starring Jimmy Fal...
# 9000  [{'name': 'Giraldi Media', 'url': 'https://www...
# 9001  [{'name': 'PRinbatonrouge', 'url': 'https://ww...
# 9002  [{'name': 'chuckzvideo', 'url': 'https://www.y...
# 9003  [{'name': 'Hang Massive', 'url': 'https://www....
# 9004                                                NaN
# 9005  [{'name': 'Warner Bros. UK', 'url': 'https://w...
# 9006                                                NaN
# 9007                                                NaN
# 9008                                                NaN
# 9009  [{'name': 'MathsGDCisCasio', 'url': 'https://w...
# 9010  [{'name': 'MathsGDCisCasio', 'url': 'https://w...
# 9011  [{'name': 'MathsGDCisCasio', 'url': 'https://w...
# 9012  [{'name': 'MathsGDCisCasio', 'url': 'https://w...
# 9013  [{'name': 'MathsGDCisCasio', 'url': 'https://w...
# 9014  [{'name': 'MathsGDCisCasio', 'url': 'https://w...
# 9015  [{'name': 'MathsGDCisCasio', 'url': 'https://w...
# 9016  [{'name': 'MathsGDCisCasio', 'url': 'https://w...
# 9017  [{'name': 'MathsGDCisCasio', 'url': 'https://w...
# 9018  [{'name': 'MathsGDCisCasio', 'url': 'https://w...
# 9019  [{'name': 'MathsGDCisCasio', 'url': 'https://w...
# 9020  [{'name': 'MathsGDCisCasio', 'url': 'https://w...
# 9021                                                NaN
# 9022  [{'name': 'Özer Dölekoğlu', 'url': 'https://ww...
# 9023  [{'name': 'The Verge', 'url': 'https://www.you...
# 9024  [{'name': 'Movieclips Trailers', 'url': 'https...
#
#                           time  \
# 0     2019-05-04T15:51:04.397Z
# 1     2019-05-04T15:16:07.495Z
# 2     2019-05-04T14:24:33.373Z
# 3     2019-05-04T14:10:05.115Z
# 4     2019-05-04T13:56:17.096Z
# 5     2019-05-04T13:36:24.194Z
# 6     2019-05-04T13:36:04.262Z
# 7     2019-05-03T22:20:56.255Z
# 8     2019-05-03T22:20:08.582Z
# 9     2019-05-03T22:19:19.939Z
# 10    2019-05-03T22:15:50.344Z
# 11    2019-05-03T22:13:00.599Z
# 12    2019-05-03T22:11:14.396Z
# 13    2019-05-03T22:11:04.567Z
# 14    2019-05-02T22:48:02.704Z
# 15    2019-05-02T22:40:24.903Z
# 16    2019-05-02T22:38:46.686Z
# 17    2019-05-02T22:36:35.806Z
# 18    2019-05-02T22:34:31.213Z
# 19    2019-05-02T22:29:08.760Z
# 20    2019-05-02T22:21:29.721Z
# 21    2019-05-02T19:10:36.222Z
# 22    2019-05-02T07:30:32.493Z
# 23    2019-05-02T07:28:17.263Z
# 24    2019-05-02T07:10:26.394Z
# 25    2019-05-02T07:06:58.309Z
# 26    2019-05-02T07:02:44.565Z
# 27    2019-05-01T16:56:19.843Z
# 28    2019-05-01T16:47:13.813Z
# 29    2019-05-01T16:44:03.104Z
# ...                        ...
# 8995  2013-06-03T12:14:51.712Z
# 8996  2013-06-03T12:13:19.188Z
# 8997  2013-06-03T12:12:04.398Z
# 8998  2013-06-03T12:10:14.434Z
# 8999  2013-05-31T09:00:08.160Z
# 9000  2013-05-31T08:59:40.268Z
# 9001  2013-05-31T08:59:15.215Z
# 9002  2013-05-31T08:57:43.740Z
# 9003  2013-05-31T08:56:34.847Z
# 9004  2013-05-31T08:56:21.109Z
# 9005  2013-05-31T08:54:07.919Z
# 9006  2013-05-31T08:51:31.128Z
# 9007  2013-05-30T20:38:23.340Z
# 9008  2013-05-30T19:41:07.486Z
# 9009  2013-05-30T13:34:08.414Z
# 9010  2013-05-30T13:33:38.684Z
# 9011  2013-05-30T13:27:05.193Z
# 9012  2013-05-30T13:20:03.731Z
# 9013  2013-05-30T13:14:29.916Z
# 9014  2013-05-30T13:08:24.099Z
# 9015  2013-05-30T13:02:43.993Z
# 9016  2013-05-30T13:01:22.800Z
# 9017  2013-05-30T12:56:12.477Z
# 9018  2013-05-30T12:49:49.775Z
# 9019  2013-05-30T12:45:31.681Z
# 9020  2013-05-30T12:36:29.574Z
# 9021  2013-05-30T11:32:30.934Z
# 9022  2013-05-23T19:51:15.893Z
# 9023  2013-05-23T19:44:58.295Z
# 9024  2013-05-23T16:56:22.071Z
#
#                                                   title  \
# 0           Watched Stromae - Papaoutai (Clip Officiel)
# 1                              Watched Me My Body And I
# 2     Watched I Did Peloton For Two Weeks Straight A...
# 3                 Watched F8 2019 keynote in 12 minutes
# 4        Watched Netflix culture deck via Reed Hastings
# 5     Watched Tuca & Bertie | Official Trailer [HD] ...
# 6     Watched Netflix Interview (1 of 3): 2018 Cultu...
# 7     Watched "You Make Me Sick So Much, Jimmy Carr"...
# 8     Watched How to Install a Hidden Kill Switch in...
# 9     Watched John Bradley Doesn’t Know What He Know...
# 10    Watched Everything Wrong With School Of Rock I...
# 11    Watched Why the World’s Best Mathematicians Ar...
# 12    Watched Iggy Azalea - Started (Official Music ...
# 13                            Watched Socially Immobile
# 14         Watched Adorable Dates from The Undateables!
# 15         Watched ME! Behind The Scenes: Je Suis Calme
# 16    Watched Sonic The Hedgehog 2019 Movie Trailer ...
# 17                Watched Pikachu uses... Foot Massage?
# 18    Watched ME! (feat. Brendon Urie of Panic! At T...
# 19                     Watched The Extinction Rebellion
# 20    Watched Every Argument Against Veganism | Ed W...
# 21    Watched I Went Vegan for 30 Days: Here's What ...
# 22    Watched New Yorkers Unite like Avengers to Egg...
# 23    Watched Dad Explains His New Polygamy Lifestyl...
# 24     Watched 7 Things You Need to STOP Doing at Night
# 25    Watched Deepfake Videos Are Getting Terrifying...
# 26       Watched Ending the Subscribe to Pewdiepie Meme
# 27           Watched Metronomy - The Look (Music Video)
# 28    Watched Daft Punk - Lose Yourself to Dance (Of...
# 29           Watched Stromae - Ta Fête (Audio Officiel)
# ...                                                 ...
# 8995  Watched T-ara N4 Palms Pool Las Vegas First Pe...
# 8996           Watched This is how you DON'T play MGS3.
# 8997                    Watched Vote Jarrett the Parrot
# 8998               Watched Don't Swallow? | Family Feud
# 8999  Watched Game of Desks (Late Night with Jimmy F...
# 9000           Watched Michael Jackson Pepsi Generation
# 9001  Watched Just call the police, baby (original v...
# 9002               Watched KNBC-TV Live On-Air Incident
# 9003  Watched Hang Massive - Once Again - 2011 ( han...
# 9004  Watched https://www.youtube.com/watch?v=zUDDiW...
# 9005  Watched Pacific Rim -- 'Oversized Robot Set' F...
# 9006  Watched https://www.youtube.com/watch?v=XjrSGs...
# 9007  Watched https://www.youtube.com/watch?v=rG5tV7...
# 9008  Watched https://www.youtube.com/watch?v=bekNKJ...
# 9009  Watched Casio hint 16 Mean and Standard Deviat...
# 9010            Watched Casio hint 10 Spreadsheet intro
# 9011  Watched Casio hint 8 Confidence Intervals pop ...
# 9012  Watched Casio hint 7b Confidence Intervals Std...
# 9013     Watched Casio hint 7a CI for known Pop std dev
# 9014  Watched Casio hint 6 Inverse Normal probabilities
# 9015          Watched Casio hint 5 Normal Probabilities
# 9016           Watched casio hint 4 Integration q7 p444
# 9017         Watched casio hint 3 binomial distribution
# 9018            Watched casio hint 2 unbiased estimates
# 9019                      Watched casio hint 1 graphing
# 9020            Watched Casio hint 9 Contingency Tables
# 9021  Watched https://www.youtube.com/watch?v=Pl1UMf...
# 9022          Watched Microsoft fails again (1998-2012)
# 9023                  Watched Microsoft Surface Keynote
# 9024  Watched Don Jon Official Trailer #1 (2013) - J...
#
#                                          titleUrl
# 0     https://www.youtube.com/watch?v=oiKj0Z_Xnjc
# 1     https://www.youtube.com/watch?v=tCbPpfIGk-s
# 2     https://www.youtube.com/watch?v=erqLKwwZCVE
# 3     https://www.youtube.com/watch?v=UtxPdezclYw
# 4     https://www.youtube.com/watch?v=2fuOs6nJSjY
# 5     https://www.youtube.com/watch?v=ZybYIJtbcu0
# 6     https://www.youtube.com/watch?v=8-4is78UJZ8
# 7     https://www.youtube.com/watch?v=Q8BeTjCjmwQ
# 8     https://www.youtube.com/watch?v=XUhXLsrZiE0
# 9     https://www.youtube.com/watch?v=qPHlaLti3g0
# 10    https://www.youtube.com/watch?v=K9oe-qbfvSo
# 11    https://www.youtube.com/watch?v=PhNUjg9X4g8
# 12    https://www.youtube.com/watch?v=flPCk8Z5XS0
# 13    https://www.youtube.com/watch?v=aOKLmYF4b20
# 14    https://www.youtube.com/watch?v=ODWJZEtBlu0
# 15    https://www.youtube.com/watch?v=lj2mZ8zDToY
# 16    https://www.youtube.com/watch?v=ssS8_y47CqE
# 17    https://www.youtube.com/watch?v=bo1YKTvM2Uc
# 18    https://www.youtube.com/watch?v=bqOfdv9i4sE
# 19    https://www.youtube.com/watch?v=obFNcN0Zc7k
# 20    https://www.youtube.com/watch?v=byTxzzztRBU
# 21    https://www.youtube.com/watch?v=otojwFSN9Gc
# 22    https://www.youtube.com/watch?v=XKvuNBssXG8
# 23    https://www.youtube.com/watch?v=pRR-aAHLRQo
# 24    https://www.youtube.com/watch?v=n5lxMoNLLA8
# 25    https://www.youtube.com/watch?v=T76bK2t2r8g
# 26    https://www.youtube.com/watch?v=Ah5MYGQBYRo
# 27    https://www.youtube.com/watch?v=sFrNsSnk8GM
# 28    https://www.youtube.com/watch?v=NF-kLy44Hls
# 29    https://www.youtube.com/watch?v=wEucb8qtBmA
# ...                                           ...
# 8995  https://www.youtube.com/watch?v=f4TPM41B6fE
# 8996  https://www.youtube.com/watch?v=NSH39aiTx2A
# 8997  https://www.youtube.com/watch?v=XKNUT3-Nvag
# 8998  https://www.youtube.com/watch?v=YHnhbEzJAS8
# 8999  https://www.youtube.com/watch?v=Gqgdyn6wg7E
# 9000  https://www.youtube.com/watch?v=po0jY4WvCIc
# 9001  https://www.youtube.com/watch?v=3LXSajHOx0w
# 9002  https://www.youtube.com/watch?v=NqsQk1hlLJc
# 9003  https://www.youtube.com/watch?v=xk3BvNLeNgw
# 9004  https://www.youtube.com/watch?v=zUDDiWtFtEM
# 9005  https://www.youtube.com/watch?v=BcsFMTjgsCM
# 9006  https://www.youtube.com/watch?v=XjrSGsNE2Tc
# 9007  https://www.youtube.com/watch?v=rG5tV7zcl1s
# 9008  https://www.youtube.com/watch?v=bekNKJoxYbQ
# 9009  https://www.youtube.com/watch?v=kTj1ia_5pvc
# 9010  https://www.youtube.com/watch?v=afMskCEvfWk
# 9011  https://www.youtube.com/watch?v=X3lssoxHDM4
# 9012  https://www.youtube.com/watch?v=6ykrmBTUXdM
# 9013  https://www.youtube.com/watch?v=O36dPj_l2aQ
# 9014  https://www.youtube.com/watch?v=JQP9sb2kLrA
# 9015  https://www.youtube.com/watch?v=E5LViG-gmMQ
# 9016  https://www.youtube.com/watch?v=rVD4WN7k_9Q
# 9017  https://www.youtube.com/watch?v=CqcOXW16xJg
# 9018  https://www.youtube.com/watch?v=N6kJzxNpUX4
# 9019  https://www.youtube.com/watch?v=8nMi8wdzC00
# 9020  https://www.youtube.com/watch?v=Bc3dAcwCNw0
# 9021  https://www.youtube.com/watch?v=Pl1UMfxa_r4
# 9022  https://www.youtube.com/watch?v=2w8rypZQDbg
# 9023  https://www.youtube.com/watch?v=jozTK-MqEXQ
# 9024  https://www.youtube.com/watch?v=6615kYTpOSU
#
# [9025 rows x 7 columns]

# %% [markdown]
# There are some parts we'd ike to make use of such as `title` that show some useful information, and others like `titleUrl` which in this project, we won't have any use for. First, we can drop everything but `title` and `time` as we don't need anything else.

# %%
# Drop columns except title and time
wh = wh[['title', 'time']]

# %% [markdown]
# We can see clearly that "Watched" is being prepended to the `title` field. Not only this, but where a video has become unavailable, we get a title like "Watched https://www.youtube.com/watch?v=rG5tV7zcl1s". Let's take a look at the percentage of videos that are no longer available in the dataset

# %%
len(wh[wh['title'].str.startswith('Watched https://www.youtube.com')]) / len(wh)
# Out:
# 0.05473684210526316

# %% [markdown]
# It's about 5%. Not too bad. Let's remove the prefix "Watched" from the titles and also drop all the unavailable videos. We'll also remove whitespace and make everything lower case for simplicitely.

# %%
import string

# Remove "Watched" from title "Watched Cat Video" -> "Cat Video"
wh['title'] = wh['title'].apply(lambda x: x[7:])

# Remove Unavailable videos
wh = wh.drop(wh[wh['title'].str.startswith('https://www.youtube.com')].index)

# Lower Case "Cat Video" -> "cat video"
wh['title'] = wh['title'].apply(lambda x: x.lower())

# Remove whitespace
wh['title'] = wh['title'].apply(lambda x: x.strip())
wh['title'] = wh['title'].apply(
    lambda x: x.translate(str.maketrans(' ', ' ', string.punctuation)))

wh.head()
# Out:
#                                                title                      time
# 0                   stromae  papaoutai clip officiel  2019-05-04T15:51:04.397Z
# 1                                   me my body and i  2019-05-04T15:16:07.495Z
# 2  i did peloton for two weeks straight and here’...  2019-05-04T14:24:33.373Z
# 3                      f8 2019 keynote in 12 minutes  2019-05-04T14:10:05.115Z
# 4             netflix culture deck via reed hastings  2019-05-04T13:56:17.096Z

# %% [markdown]
# We only want the date from the `time` field, as the time is too granular for this particular visualisation. Let's convert this attribute to just contain a `datetime` object with the date

# %%
import datetime as dt

def get_date(datetime_str):
    return dt.datetime.strptime(datetime_str.split('T')[0], '%Y-%m-%d')

wh['time'] = wh['time'].apply(lambda x: get_date(x))

wh.head()
# Out:
#                                                title       time
# 0                   stromae  papaoutai clip officiel 2019-05-04
# 1                                   me my body and i 2019-05-04
# 2  i did peloton for two weeks straight and here’... 2019-05-04
# 3                      f8 2019 keynote in 12 minutes 2019-05-04
# 4             netflix culture deck via reed hastings 2019-05-04

# %% [markdown]
# ## Feature Engineering
#
# Now we have the dataframe with the important information from the original history JSON we downloaded. We're now going to add the following features in order to get a better representation of the data. We have a large collection of titles, but the title "Body Workout Exercise" and "Full Body Workout" have very similar themes, but are treated as distinct occurances unless we find some way to group entries with similar themes. We need a way to:
#
# * Extract key themes from a video title
# * Find other videos that have this theme

# %% [markdown]
# ### Keyword Analysis
#
# In order to get aggregated meaning of the titles, we can look at the keywords in the titles.

# %% [markdown]
# #### Tokenizing
#
# We could find the distribution of keywords such as "XBOX" or "Full-body Workout" over the range of the dataset. Notice that keywords could appear in the form of unigrams (one word) or bigrams (two words together) such as the latter example. We also want to remove stop words such as "and" and "with" in our tokens, as these won't provide any additional value to this example.

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

def find_ngrams(input_list, n):
    if n > 1:
        return zip(*(input_list[i:] for i in range(n)))
    else:
        return input_list

# Split words and remove stopwords
wh['unigrams'] = wh['title'].apply(lambda x: [word for word in x.split(' ') if word not in stop_words and word != ''])
wh['bigrams'] = wh['unigrams'].apply(lambda x: list(find_ngrams(x, 2)))
wh.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Oliver\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
#                                                title       time  \
# 0                   stromae  papaoutai clip officiel 2019-05-04
# 1                                   me my body and i 2019-05-04
# 2  i did peloton for two weeks straight and here’... 2019-05-04
# 3                      f8 2019 keynote in 12 minutes 2019-05-04
# 4             netflix culture deck via reed hastings 2019-05-04
#
#                                             unigrams  \
# 0               [stromae, papaoutai, clip, officiel]
# 1                                             [body]
# 2  [peloton, two, weeks, straight, here’s, happened]
# 3                   [f8, 2019, keynote, 12, minutes]
# 4      [netflix, culture, deck, via, reed, hastings]
#
#                                              bigrams
# 0  [(stromae, papaoutai), (papaoutai, clip), (cli...
# 1                                                 []
# 2  [(peloton, two), (two, weeks), (weeks, straigh...
# 3  [(f8, 2019), (2019, keynote), (keynote, 12), (...
# 4  [(netflix, culture), (culture, deck), (deck, v...

# %% [markdown]
# By creating a bag of words, we can explore the frequency of the unigrams and bigrams that are appearing in the dataset.

# %%
from collections import Counter

# Create N-Gram Counters
def get_counter_from_column(df, column_name):
    ct = Counter()
    for row in df[column_name]:
        for element in row:
            ct[element] += 1
    return ct

bag_1 = get_counter_from_column(wh, 'unigrams')
bag_2 = get_counter_from_column(wh, 'bigrams')

print("Bag 1\n", bag_1.most_common(10))
print("Bag 2\n", bag_2.most_common(10))
# Out:
# Bag 1
#  [('video', 811), ('official', 606), ('trailer', 283), ('removed', 239), ('music', 218), ('1', 205), ('2', 196), ('hd', 190), ('life', 176), ('vs', 173)]
# Bag 2
#  [(('video', 'removed'), 239), (('official', 'video'), 209), (('music', 'video'), 154), (('official', 'music'), 137), (('official', 'trailer'), 135), (('movie', 'hd'), 53), (('trailer', '1'), 53), (('glass', 'animals'), 43), (('trailer', 'hd'), 43), (('part', '1'), 42)]

# %%
print("movies: {}".format(bag_1['movies']))
print("movie: {}".format(bag_1['movie']))
# Out:
# movies: 8
# movie: 105

# %% [markdown]
# #### Combine Pluralisms
#
# We can see from the following code snippet that a singular word's plural can appear in the bag of words together. Semantically they mean the same thing, therefore we should find a way to combine these instances. In this example, we're taking every regular noun (You just have to add s to pluralise) that has both an occurence of itself and this plural in our unigrams. We then pick one of these with the most occurances and then replace this in both the bag of words and the dataframe.

# %%
# Pick singular or plural for most common 500 words
def replace_count(counter, removed, added):
    counter[added] += counter[removed]
    del counter[removed]
    
remove_words = []
for word in bag_1.most_common(1000):
    word = word[0]
    if word.endswith('s'):
        singular = word[:-1]
        plural = word
    else:
        singular = word
        plural = word + 's'
    if plural in bag_1 and singular in bag_1:
        if bag_1[plural] >= bag_1[singular]:
            remove_words.append((singular, plural))
        else:
            remove_words.append((plural, singular))

for (removed, added) in remove_words:
    replace_count(bag_1, removed, added)
    wh['unigrams'] = wh['unigrams'].apply(lambda x: [added if unigram == removed else unigram for unigram in x])
    
bag_1.most_common(10)
# Out:
# [('video', 833),
#  ('official', 606),
#  ('trailer', 294),
#  ('removed', 239),
#  ('new', 223),
#  ('music', 218),
#  ('1', 205),
#  ('2', 197),
#  ('vs', 191),
#  ('hd', 190)]

# %%
#!/usr/bin/env python

# Imports
import spacy
import itertools
import plotly.figure_factory as ff
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import numpy as np
import random
from datetime import datetime, timedelta
import plotly.graph_objs as go
import plotly.offline as py
import operator
import functools
import nltk

# %%
print(bag_1['glass'])
print(bag_1['animals'])
print(bag_2[('glass', 'animals')])
# Out:
# 51
# 53
# 43

# %% [markdown]
# #### Duplicates in bigrams
#
# We now also have another problem to address. If we were to combine our unigrams and bigrams now and look at the distributions of each keyword, we'd get duplicates. For example the British band "Glass Animals" appears 43 times. "glass" and "animals" occurances are largely contributed by the band's name. If we assume that if a singular word's occurs less than three times much as the respective bigram does, then it's contribution was most likely due to the bigram. Therefore we can remove it. Likewise, if the bigram appears less than a third as many times as the respective unigram, then we can remove it from the dataset.
#
# While this is more anecdotal, this was able to extract some more of the key bigrams that I knew where in the dataset. Obviously this requires more rigor to have reproducable outcomes for other datasets.

# %%
THRESHOLD = 0.3
for bigram in bag_2.most_common(1000):
    # print("{}: {}".format(bigram[0][0], bag_1[bigram[0][0]] * 0.75))
    if (bag_1[bigram[0][0]] * THRESHOLD) <= bag_2[bigram[0]]:
        del bag_1[bigram[0][0]]
        if (bag_1[bigram[0][1]] * THRESHOLD) <= bag_2[bigram[0]]:
            del bag_1[bigram[0][1]]
    else:
        del bag_2[bigram[0]]
print(bag_1[('video',)])
wh['ngrams'] = wh['unigrams'] + wh['bigrams']
bag_1_2 = (bag_1 + bag_2)
# Out:
# 0

# %%
bag_1_2.most_common(10)
# Out:
# [('video', 833),
#  ('removed', 239),
#  ('new', 223),
#  (('official', 'video'), 209),
#  ('1', 205),
#  ('2', 197),
#  ('vs', 191),
#  ('hd', 190),
#  ('day', 189),
#  ('life', 177)]
